# %%
import pandas as pd
import statsmodels
import matplotlib.pyplot as plt
import math
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
from scipy.fftpack import fft
import random
from random import randrange
random.seed(1)

# %%
x_axis = np.arange(0, 29-1/288, 1/288).tolist()
np_cpu = np.load("wetransfer-2ee104//google-cpu-full.npy")

# full_cpu is a list of pandas series of the cpu utilisation of all machines
# just a lazy way of converting nd-arrays to pd-series
full_cpu = []
for x in range (0,len(np_cpu)):
    full_cpu.append(pd.Series(np_cpu[x], index = x_axis))

# %%
plt.figure(figsize=(20,10))
plt.plot(x_axis,full_cpu[0], color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 1 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(x_axis,full_cpu[1], color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 2 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(x_axis,full_cpu[2], color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 3 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.grid()
plt.show()

# %% [markdown]
# ## Stationarity
#
# - Does the data have the same statistical property (Variance, Mean, Autocorrelation) throughout the whole series.
# - Most analytics procedure in time-series analysis require data to be stationary or at least the procedure itself i.e. the model function will make the data stationary during the model setup.
# - If the data is not stationary, there are transformations that can be used to make the data stationary.
#
# ### Differencing:
# - Adjust data according to the time spent that differ in variance or mean. Make the statistics the same throughout the whole series.
# - Used extensively in ARIMA models
#
# ### Augmented Dicky-Fuller Test:
# - Test for stationarity
# - Removes autocorrelation and then tests for non-statinarity
# - Focuses on equal mean and equal variance though the entire series
# - Null hypothesis, h0 = The series is non-stationary
# - The more negative the test, the stronger the rejection of H0
# - Take stationarity: p-value < 0.05

# %%
def stationarity_test(timeseries, info = False):
    '''Augmented Dickey-Fuller test for stationarity'''
    from statsmodels.tsa.stattools import adfuller
    df_test = adfuller(timeseries, autolag = "AIC")
    df_list = [df_test[0],df_test[1]<0.05,df_test[1],df_test[2],df_test[3]]
    df_output = pd.Series(df_list, index = ["Test Statistic", 
                                              "Stationarity",
                                              "p-value", 
                                              "Number of Lags Used",
                                              "Number of Observations Used"
                                             ])
    
    if(info):
        print("Results of Dickey-Fuller Test:")
        print(df_output)
        
    return df_output

def bulk_stationarity(timeseries, number_of_samples = 10):
    '''
    - takes in a list of timeseries
    - randomly chooses number_of_samples of timeseries
    - outputs a df detailing if the timeseries is stationary
    '''
    
    from random import randrange
    random_number = []
    for x in range(0,number_of_samples):
        random_number.append(randrange(len(full_cpu)))

    random_number = np.sort(random_number) 

    stationarity_list = []
    for x in random_number:
        stationarity_list.append(stationarity_test(full_cpu[x]))
    df_output = pd.DataFrame(stationarity_list, columns = ["Test Statistic", 
                                              "Stationarity",
                                              "p-value", 
                                              "Number of Lags Used",
                                              "Number of Observations Used"
                                             ], index = random_number)    
    return df_output

# %%
# Randomly choose about 2% of the timeseries to check if they are stationary
stationarity_of_120 = bulk_stationarity(full_cpu, number_of_samples = 240)

# %%
stationarity_of_120['Stationarity'].value_counts()
# Out:
# True     239
# False      1
# Name: Stationarity, dtype: int64

# %% [markdown]
# ### Stationarity of Dataset
# 2% of the timeseries are chosen at random and are tested on their stationarity using the Augmented Dicky-Fuller test. Out of the 2% chosen, 0.416667% are non-stationary. It is hence estimated that 99.6% of all of the timeseries are stationary which is equivalent to 12424 out of 12476 timeseries

# %%
len(full_cpu)
# Out:
# 12476

# %% [markdown]
# ## ACF and PACF Plot
# - Gives the correlation between different lags
# - PACF is adjusted for all earlier lags

# %%
def plot_autocorrelation(timeseries):
    from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
    fig, (ax1, ax2) = plt.subplots(2,1,figsize = (20,8))
    ax1.grid()
    ax2.grid()
    plot_acf(timeseries, lags = 20, ax=ax1)
    plot_pacf(timeseries, lags = 20, ax = ax2)

# %%
plot_autocorrelation(full_cpu[5])

# %%
def decompose(timeseries, bar_f = 288, sub_plot = False, plot_single = False):
    import statsmodels.api as sm
    timeseries_stl = sm.tsa.seasonal_decompose(timeseries, freq = bar_f)
    
    if(sub_plot):
        fog, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize = (20,20))
        timeseries.plot(ax = ax1)
        timeseries_stl.trend.plot(ax = ax2)
        timeseries_stl.seasonal.plot(ax = ax3)
        timeseries_stl.resid.plot(ax = ax4)
        ax1.grid()
        ax2.grid()
        ax3.grid()
        ax4.grid()
        ax1.set_title("Timeseries")
        ax2.set_title("Trend")
        ax3.set_title("Seasonality")
        ax4.set_title("Residuals")
        plt.tight_layout()
        
    if(plot_single):
        plt.figure(figsize=(20,10))
        plt.plot(x_axis,timeseries_stl.trend, color = 'blue', label = "Trend") 
        plt.plot(x_axis,timeseries_stl.seasonal, color = 'red', label = "Seasonal") 
        plt.plot(x_axis,timeseries_stl.resid, color = 'green', label = "Residual") 
        plt.title("Decomposition vs Days")  
        plt.xlabel("Days")  
        plt.ylabel("Decomposed Time Series")  
        plt.legend()
        plt.grid()
        plt.show()
        
    return timeseries_stl

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)
decompose(full_cpu[rand], plot_single = True, bar_f = 288*7)
decompose(full_cpu[rand], plot_single = True, bar_f = 288)
# Out:
# Random Number:  9048

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)
decompose(full_cpu[rand], plot_single = True, bar_f = 288*7)
decompose(full_cpu[rand], plot_single = True, bar_f = 288)
# Out:
# Random Number:  5641

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)
decompose(full_cpu[rand], plot_single = True, bar_f = 288*7)
decompose(full_cpu[rand], plot_single = True, bar_f = 288)
# Out:
# Random Number:  8038

# %%
def compare_variance(timeseries_list, number_of_samples):
    
    import statsmodels.api as sm
    from random import randrange
    
    random_number = []
    for x in range(0,number_of_samples):
        random_number.append(randrange(len(full_cpu)))

    headers = ["Days Seasonal Absolute Mean", 
                                 "Days Residual Absolute Mean",
                                 "Weeks Seasonal Absolute Mean",
                                 "Weeks Residual Absolute Mean"]
    random_number = np.sort(random_number)
    temp_list = []
    
    for x in random_number:
        decompose_day = decompose(timeseries_list[x], bar_f = 288)
        decompose_week = decompose(timeseries_list[x], bar_f = 288*7)
        temp_list.append([decompose_day.seasonal.abs().mean(), 
                   decompose_day.resid.abs().mean(), 
                   decompose_week.seasonal.abs().mean(),
                   decompose_week.resid.abs().mean()
                  ])
    df = pd.DataFrame(temp_list, columns = headers, index = random_number)    
        
    return df

# %%
compare_variance(full_cpu, 10)
# Out:
#        Days Seasonal Absolute Mean  Days Residual Absolute Mean  \
# 423                       0.008803                     0.058614
# 2412                      0.016953                     0.058638
# 3659                      0.013352                     0.036803
# 3972                      0.010161                     0.055908
# 6032                      0.015693                     0.074551
# 8556                      0.009075                     0.055706
# 9132                      0.048446                     0.060764
# 10017                     0.012617                     0.042046
# 10982                     0.011295                     0.049523
# 12382                     0.012258                     0.051218
#
#        Weeks Seasonal Absolute Mean  Weeks Residual Absolute Mean
# 423                        0.048007                      0.055345
# 2412                       0.058232                      0.058614
# 3659                       0.031578                      0.037572
# 3972                       0.052102                      0.053302
# 6032                       0.049509                      0.069621
# 8556                       0.041047                      0.047159
# 9132                       0.081873                      0.054469
# 10017                      0.033360                      0.040944
# 10982                      0.030528                      0.043807
# 12382                      0.044979                      0.053570

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)

autocorelation = [full_cpu[rand].autocorr(n) for n in range(len(full_cpu[rand]))]
plt.figure(figsize=(20,5))
plt.plot(x_axis, autocorelation, color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 1 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# Random Number:  9336

# %% [markdown]
# 0.3-0.6 medium correlation
# 0.1 low correlation
# > 0.7 high correlation
# hard code autocorrelation function
# do circular correlation
#
# check correlation matrix

# %%
def corelate(timeseries, lag = 0, divide = 1):
    answer = 0
    for x in range (lag, len(timeseries)):
        answer = answer + timeseries[x]*timeseries[x-lag]
        
    return answer

# %%
plt.figure(figsize=(20,10))
plt.plot(x_axis,full_cpu[9336], color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 1 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.grid()
plt.show()

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)

autocorelation = [full_cpu[rand].autocorr(n) for n in range(len(full_cpu[rand]))]
plt.figure(figsize=(20,5))
plt.plot(x_axis, autocorelation, color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 1 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# Random Number:  2049

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)

autocorelation = [full_cpu[rand].autocorr(n) for n in range(len(full_cpu[rand]))]
plt.figure(figsize=(20,5))
plt.plot(x_axis, autocorelation, color = 'blue', marker = "x")  
plt.title("Mean CPU Usage Rate 1 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# Random Number:  3202

# %%
from random import randrange
rand = randrange(len(full_cpu))
print("Random Number: ", rand)

autocorelation = [full_cpu[rand].autocorr(n) for n in range(len(full_cpu[rand]))]
plt.figure(figsize=(20,5))
plt.plot(x_axis, autocorelation, color = 'blue')  
plt.title("Mean CPU Usage Rate 1 vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# Random Number:  7288

# %%
def correlation_matrix(timeseries_list, number_of_samples):    
    from random import randrange
    
    rand_list = []
    for x in range(0,number_of_samples):
        rand_list.append(randrange(len(timeseries_list)))
        
    rand_list = sorted(rand_list)
    
    df = []
    for x in rand_list:
        df.append(timeseries_list[x])
        
    return pd.DataFrame(df, index = rand_list).transpose().corr()

# %%
correlation_matrix(full_cpu, 10)
# Out:
#           3773      3913      3986      4883      7435      8468      8564   \
# 3773   1.000000  0.416475  0.517606  0.316570  0.394318  0.296362  0.406923
# 3913   0.416475  1.000000  0.633909  0.441608  0.441142  0.240148  0.466439
# 3986   0.517606  0.633909  1.000000  0.532563  0.529157  0.303568  0.516911
# 4883   0.316570  0.441608  0.532563  1.000000  0.376832  0.321566  0.340256
# 7435   0.394318  0.441142  0.529157  0.376832  1.000000  0.174036  0.430581
# 8468   0.296362  0.240148  0.303568  0.321566  0.174036  1.000000  0.256439
# 8564   0.406923  0.466439  0.516911  0.340256  0.430581  0.256439  1.000000
# 9374   0.412077  0.454853  0.395408  0.304511  0.308937  0.298249  0.355994
# 11073  0.373738  0.453455  0.582566  0.538020  0.481341  0.332319  0.341058
# 11463  0.527172  0.461423  0.493641  0.308204  0.460092  0.248413  0.466967
#
#           9374      11073     11463
# 3773   0.412077  0.373738  0.527172
# 3913   0.454853  0.453455  0.461423
# 3986   0.395408  0.582566  0.493641
# 4883   0.304511  0.538020  0.308204
# 7435   0.308937  0.481341  0.460092
# 8468   0.298249  0.332319  0.248413
# 8564   0.355994  0.341058  0.466967
# 9374   1.000000  0.231034  0.391854
# 11073  0.231034  1.000000  0.374193
# 11463  0.391854  0.374193  1.000000

# %%
len(full_cpu[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-54e477b0815f> in <module>
# ----> 1 len(full_cpu[0])
#
# NameError: name 'full_cpu' is not defined

# %%
list1 = [10, 20, 4, 45, 99] 
  
k=max(list1[0],list1[1]) 
secondmax=min(list1[0],list1[1]) 
  
for i in range(2,len(list1)): 
    if list1[i]>k: 
        secondmax=k
        k=list1[i] 
    else: 
        if list1[i]>secondmax: 
            secondmax=list1[i] 
  
print("Second highest number is : ",str(secondmax))
# Out:
# Second highest number is :  45

# %%
del max

# %%
plt.figure(figsize=(20,10))
plt.plot(x_axis,full_cpu[0], color = 'blue', marker = "x")  
plt.title("Machine 1 Mean CPU Usage Rate vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.grid()
plt.savefig('Machine 1.png')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(x_axis,full_cpu[1], color = 'blue', marker = "x")  
plt.title("Machine 2 Mean CPU Usage Rate vs Days")  
plt.xlabel("Days")  
plt.ylabel("Mean CPU Usage")  
plt.grid()
plt.savefig('Machine 2.png')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot([1,1,1,1], color = 'blue', marker = "o", label = "Example Machine 1")  
plt.plot([4,4,4,4], color = 'red', marker = "o", label = "Example Machine 2")
plt.plot([1,1.25,1.9,3], color = 'green', marker = "o", label = "Example Machine 3")
plt.title("Most recent four points of machines", fontsize = 18)
plt.xlabel("Time (sample)", fontsize = 15)  
plt.ylabel("Mean CPU Usage", fontsize = 15)  
plt.grid()
plt.legend()
plt.savefig('Cluster1.png')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(x_axis, full_cpu[1].to_list())
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Mean CPU Usage Rate of Machine 1", fontsize = 18)
plt.ylabel("Mean CPU Usage Rate", fontsize = 15) 
plt.xlabel("Time (Day)", fontsize = 15)
plt.savefig("Machine1_timeseries")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(x_axis, full_cpu[2].to_list())
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Mean CPU Usage Rate of Machine 2", fontsize = 18)
plt.ylabel("Mean CPU Usage Rate", fontsize = 15) 
plt.xlabel("Time (Day)", fontsize = 15)
plt.savefig("Machine2_timeseries")
plt.show()

# %%
x_axis = np.arange(0, 29-1/288, 1/288).tolist()
np_mem = np.load("wetransfer-2ee104//google-mem-full.npy")

# full_cpu is a list of pandas series of the cpu utilisation of all machines
# just a lazy way of converting nd-arrays to pd-series
full_mem = []
for x in range (0,len(np_mem)):
    full_mem.append(pd.Series(np_mem[x], index = x_axis))

# %%
plt.figure(figsize=(15,5))
plt.plot(x_axis, full_cpu[10875].to_list())
plt.plot(x_axis[288*1:288*2], full_cpu[10875].to_list()[288*1:288*2], color = "red")
plt.plot(x_axis[(288*5):(288*5+288)], full_cpu[10875].to_list()[(288*5):(288*5+288)], color = "green")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Mean CPU Usage Rate of Machine 10875", fontsize = 18)
plt.ylabel("Mean CPU Usage Rate", fontsize = 15) 
plt.xlabel("Time (Day)", fontsize = 15)
plt.savefig("Machine10875_timeseries")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(x_axis, full_mem[2].to_list())
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Mean Memory Usage Rate of Machine 2", fontsize = 18)
plt.ylabel("Mean Memory Usage Rate", fontsize = 15) 
plt.xlabel("Time (Day)", fontsize = 15)
plt.savefig("Machine2_timeseries_mem")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(x_axis, full_cpu[11821].to_list())
plt.plot(x_axis[288*1:288*2], full_cpu[11821].to_list()[288*1:288*2], color = "red")
plt.plot(x_axis[(288*5):(288*5+288)], full_cpu[11821].to_list()[(288*5):(288*5+288)], color = "green")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Mean CPU Usage Rate of Machine 11821", fontsize = 18)
plt.ylabel("Mean CPU Usage Rate", fontsize = 15) 
plt.xlabel("Time (Day)", fontsize = 15)
plt.savefig("Machine11821_timeseries")
plt.show()

# %%
stationarity_test(full_cpu[1])
# Out:
# Test Statistic                    -7.71045
# Stationarity                          True
# p-value                        1.26798e-11
# Number of Lags Used                     24
# Number of Observations Used           8326
# dtype: object

# %%
get_rand = list()
for x in range(0,6):
    get_rand.append(random.randrange(0, len(np_cpu)))
    
get_rand = sorted(get_rand)
